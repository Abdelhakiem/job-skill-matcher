# %%
# imports
import pandas as pd
import numpy as np
import pickle

# %%
RAW_DATA_PATH = '../data/raw/survey_results_public.csv'

# Constants:
PROCESSED_DATA_PATH = '../data/processed'
TARGET_COL = 'DevType'

with open('../data/variables/possible_predictors.pkl', 'rb') as f:
    PREDICTOR_COLS = pickle.load(f)

# %% [markdown]
# ### Helper functions:

# %%
# functions:
def check_multiple_answers(df, col):
    return df[col].str.contains(';').any() == True

def split_answers(df, col):
    return df[col].str.split(';')

# %%
df_raw = pd.read_csv(RAW_DATA_PATH).loc[:, PREDICTOR_COLS ]
df_raw.sample(3, random_state=42).T
# Out:
#                                                                           76172  \
# EdLevel                            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# YearsCode                                                                     5
# YearsCodePro                                                                  7
# DevType                       Developer, front-end;Developer, desktop or ent...
# OrgSize                                                    100 to 499 employees
# LanguageHaveWorkedWith                                                 C;C#;PHP
# LanguageWantToWorkWith                      C;C#;HTML/CSS;JavaScript;TypeScript
# DatabaseHaveWorkedWith                                                 Firebase
# DatabaseWantToWorkWith        DynamoDB;Elasticsearch;Firebase;MongoDB;MySQL;...
# PlatformHaveWorkedWith                                         AWS;DigitalOcean
# PlatformWantToWorkWith        AWS;DigitalOcean;Google Cloud Platform;Heroku;...
# WebframeHaveWorkedWith                            Angular;jQuery;Laravel;Vue.js
# WebframeWantToWorkWith        Angular;ASP.NET Core ;Django;Express;FastAPI;R...
# MiscTechHaveWorkedWith                              .NET Framework;React Native
# MiscTechWantToWorkWith        .NET Core / .NET 5;Flutter;Hadoop;Keras;NumPy;...
# ToolsTechHaveWorkedWith                                                  Docker
# ToolsTechWantToWorkWith                                              Docker;Git
# NEWCollabToolsHaveWorkedWith                                       Sublime Text
# NEWCollabToolsWantToWorkWith        Atom;Emacs;Visual Studio;Visual Studio Code
# OpSys                                                                   Windows
#
#                                                                      30324  \
# EdLevel                       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# YearsCode                                                               11
# YearsCodePro                                                             9
# DevType                              Developer, mobile;Academic researcher
# OrgSize                                                 20 to 99 employees
# LanguageHaveWorkedWith                            Objective-C;Python;Swift
# LanguageWantToWorkWith                            Objective-C;Python;Swift
# DatabaseHaveWorkedWith                                              SQLite
# DatabaseWantToWorkWith                                              SQLite
# PlatformHaveWorkedWith                                                 NaN
# PlatformWantToWorkWith                                                 NaN
# WebframeHaveWorkedWith                                                 NaN
# WebframeWantToWorkWith                                                 NaN
# MiscTechHaveWorkedWith                                                 NaN
# MiscTechWantToWorkWith                                                 NaN
# ToolsTechHaveWorkedWith                                                Git
# ToolsTechWantToWorkWith                                 Ansible;Docker;Git
# NEWCollabToolsHaveWorkedWith         Sublime Text;Visual Studio Code;Xcode
# NEWCollabToolsWantToWorkWith         Sublime Text;Visual Studio Code;Xcode
# OpSys                                                                MacOS
#
#                                                                           25768
# EdLevel                       Some college/university study without earning ...
# YearsCode                                                                     4
# YearsCodePro                                                   Less than 1 year
# DevType                       Developer, desktop or enterprise applications;...
# OrgSize                                                      20 to 99 employees
# LanguageHaveWorkedWith                                          C#;HTML/CSS;SQL
# LanguageWantToWorkWith        Bash/Shell;C#;F#;JavaScript;PowerShell;Python;SQL
# DatabaseHaveWorkedWith                               Microsoft SQL Server;MySQL
# DatabaseWantToWorkWith                      MariaDB;Microsoft SQL Server;Oracle
# PlatformHaveWorkedWith                                                      NaN
# PlatformWantToWorkWith                                                      NaN
# WebframeHaveWorkedWith                                                  ASP.NET
# WebframeWantToWorkWith                                                 React.js
# MiscTechHaveWorkedWith                                           .NET Framework
# MiscTechWantToWorkWith        .NET Framework;.NET Core / .NET 5;Flutter;Reac...
# ToolsTechHaveWorkedWith                                             Git;Xamarin
# ToolsTechWantToWorkWith                                             Git;Xamarin
# NEWCollabToolsHaveWorkedWith  Eclipse;Notepad++;Sublime Text;Visual Studio;V...
# NEWCollabToolsWantToWorkWith  Android Studio;IPython/Jupyter;Notepad++;Visua...
# OpSys                                                                   Windows

# %% [markdown]
# # Preprocessing:
#
# ## Data Type conversion
# - Data type conversion: `YearsCode` , `YearsCodePro` from object to int16
#
#     Issues: 'Less than 1 year' ,'More than 50 years' , nan

# %%
df_processed = df_raw.copy()
# replacing 'Less than 1 year' with 0

df_processed.loc[df_processed['YearsCode'] == 'Less than 1 year', 'YearsCode'] = '0'
df_processed.loc[df_processed['YearsCodePro'] == 'Less than 1 year', 'YearsCodePro'] = '0'

# replacing 'More than 50 years' with 51
df_processed.loc[df_processed['YearsCode'] == 'More than 50 years', 'YearsCode'] = '51'
df_processed.loc[df_processed['YearsCodePro'] == 'More than 50 years', 'YearsCodePro'] = '51'


# converting to numeric
df_processed['YearsCode'] = df_processed['YearsCode'].astype(np.float32)
df_processed['YearsCodePro'] = df_processed['YearsCodePro'].astype(np.float32)

# %%
df_processed.dtypes
# Out:
# EdLevel                          object
# YearsCode                       float32
# YearsCodePro                    float32
# DevType                          object
# OrgSize                          object
# LanguageHaveWorkedWith           object
# LanguageWantToWorkWith           object
# DatabaseHaveWorkedWith           object
# DatabaseWantToWorkWith           object
# PlatformHaveWorkedWith           object
# PlatformWantToWorkWith           object
# WebframeHaveWorkedWith           object
# WebframeWantToWorkWith           object
# MiscTechHaveWorkedWith           object
# MiscTechWantToWorkWith           object
# ToolsTechHaveWorkedWith          object
# ToolsTechWantToWorkWith          object
# NEWCollabToolsHaveWorkedWith     object
# NEWCollabToolsWantToWorkWith     object
# OpSys                            object
# dtype: object

# %% [markdown]
# ## Needed preprocessing:
# -  Split multiple answers `;`

# %%
cat_cols = df_processed.select_dtypes(include=['object']).columns.tolist()
for col in cat_cols:
    print(f'Column {col} :')
    if check_multiple_answers(df_processed, col):
        print('Contains multiple answers')
        modified_series = split_answers(df_processed, col)
        mask_null = modified_series.isnull()
        modified_series.loc[mask_null] = modified_series.loc[mask_null].apply(lambda x: [])
        df_processed[col] = modified_series
        print('Splited')
    else:
        print('No multiple answers')
    print(f'\n','---'*5)
print('Done')
# Out:
# Column EdLevel :
# No multiple answers
#
#  ---------------
# Column DevType :
# No multiple answers
#
#  ---------------
# Column OrgSize :
# No multiple answers
#
#  ---------------
# Column LanguageHaveWorkedWith :
# No multiple answers
#
#  ---------------
# Column LanguageWantToWorkWith :
# No multiple answers
#
#  ---------------
# Column DatabaseHaveWorkedWith :
# No multiple answers
#
#  ---------------
# Column DatabaseWantToWorkWith :
# No multiple answers
#
#  ---------------
# Column PlatformHaveWorkedWith :
# No multiple answers
#
#  ---------------
# Column PlatformWantToWorkWith :
# No multiple answers
#
#  ---------------
# Column WebframeHaveWorkedWith :
# No multiple answers
#
#  ---------------
# Column WebframeWantToWorkWith :
# No multiple answers
#
#  ---------------
# Column MiscTechHaveWorkedWith :
# No multiple answers
#
#  ---------------
# Column MiscTechWantToWorkWith :
# No multiple answers
#
#  ---------------
# Column ToolsTechHaveWorkedWith :
# No multiple answers
#
#  ---------------
# Column ToolsTechWantToWorkWith :
# No multiple answers
#
#  ---------------
# Column NEWCollabToolsHaveWorkedWith :
# No multiple answers
#
#  ---------------
# Column NEWCollabToolsWantToWorkWith :
# No multiple answers
#
#  ---------------
# Column OpSys :
# No multiple answers
#
#  ---------------
# Done

# %% [markdown]
# ##### Verifying results

# %%
index = df_processed.sample(3).index
display(
    df_raw.loc[index, :] , 
    df_processed.loc[index, :]
)
# Out:
#                                                  EdLevel YearsCode  \
# 61918       Bachelor’s degree (B.A., B.S., B.Eng., etc.)        25
# 12027       Bachelor’s degree (B.A., B.S., B.Eng., etc.)        10
# 68485  Some college/university study without earning ...         6
#
#       YearsCodePro                                            DevType  \
# 61918           20  Developer, desktop or enterprise applications;...
# 12027          NaN                                            Student
# 68485          NaN                                                NaN
#
#                     OrgSize                       LanguageHaveWorkedWith  \
# 61918  100 to 499 employees              HTML/CSS;JavaScript;Python;Ruby
# 12027                   NaN                            C;C++;Java;Python
# 68485                   NaN  C;C#;Delphi;HTML/CSS;Java;Matlab;Python;SQL
#
#               LanguageWantToWorkWith DatabaseHaveWorkedWith  \
# 61918  Elixir;Go;HTML/CSS;Julia;Ruby       PostgreSQL;Redis
# 12027                   C;C++;Python                    NaN
# 68485             C;C#;Matlab;Python                  MySQL
#
#                          DatabaseWantToWorkWith PlatformHaveWorkedWith  \
# 61918  Cassandra;Elasticsearch;PostgreSQL;Redis       AWS;DigitalOcean
# 12027                                       NaN                    NaN
# 68485                                       NaN                    NaN
#
#                        PlatformWantToWorkWith WebframeHaveWorkedWith  \
# 61918  AWS;DigitalOcean;Google Cloud Platform           Flask;Vue.js
# 12027                                     NaN                    NaN
# 68485                                     NaN                    NaN
#
#       WebframeWantToWorkWith   MiscTechHaveWorkedWith MiscTechWantToWorkWith  \
# 61918    Flask;Svelte;Vue.js                      NaN                    NaN
# 12027                    NaN                      NaN                    NaN
# 68485                    NaN  .NET Framework;NumPy;Qt                    NaN
#
#       ToolsTechHaveWorkedWith          ToolsTechWantToWorkWith  \
# 61918              Docker;Git  Docker;Git;Kubernetes;Terraform
# 12027                     Git                              Git
# 68485            Git;Unity 3D                     Git;Unity 3D
#
#                             NEWCollabToolsHaveWorkedWith  \
# 61918                                                Vim
# 12027      IntelliJ;Vim;Visual Studio;Visual Studio Code
# 68485  Eclipse;Notepad++;Visual Studio;Visual Studio ...
#
#                             NEWCollabToolsWantToWorkWith    OpSys
# 61918                         IPython/Jupyter;Neovim;Vim    MacOS
# 12027                             Vim;Visual Studio Code  Windows
# 68485  Eclipse;Notepad++;Visual Studio;Visual Studio ...  Windows
#                                                  EdLevel  YearsCode  \
# 61918       Bachelor’s degree (B.A., B.S., B.Eng., etc.)       25.0
# 12027       Bachelor’s degree (B.A., B.S., B.Eng., etc.)       10.0
# 68485  Some college/university study without earning ...        6.0
#
#        YearsCodePro                                            DevType  \
# 61918          20.0  [Developer, desktop or enterprise applications...
# 12027           NaN                                          [Student]
# 68485           NaN                                                 []
#
#                     OrgSize  \
# 61918  100 to 499 employees
# 12027                   NaN
# 68485                   NaN
#
#                                   LanguageHaveWorkedWith  \
# 61918               [HTML/CSS, JavaScript, Python, Ruby]
# 12027                             [C, C++, Java, Python]
# 68485  [C, C#, Delphi, HTML/CSS, Java, Matlab, Python...
#
#                     LanguageWantToWorkWith DatabaseHaveWorkedWith  \
# 61918  [Elixir, Go, HTML/CSS, Julia, Ruby]    [PostgreSQL, Redis]
# 12027                     [C, C++, Python]                     []
# 68485              [C, C#, Matlab, Python]                [MySQL]
#
#                               DatabaseWantToWorkWith PlatformHaveWorkedWith  \
# 61918  [Cassandra, Elasticsearch, PostgreSQL, Redis]    [AWS, DigitalOcean]
# 12027                                             []                     []
# 68485                                             []                     []
#
#                            PlatformWantToWorkWith WebframeHaveWorkedWith  \
# 61918  [AWS, DigitalOcean, Google Cloud Platform]        [Flask, Vue.js]
# 12027                                          []                     []
# 68485                                          []                     []
#
#         WebframeWantToWorkWith       MiscTechHaveWorkedWith  \
# 61918  [Flask, Svelte, Vue.js]                           []
# 12027                       []                           []
# 68485                       []  [.NET Framework, NumPy, Qt]
#
#       MiscTechWantToWorkWith ToolsTechHaveWorkedWith  \
# 61918                     []           [Docker, Git]
# 12027                     []                   [Git]
# 68485                     []         [Git, Unity 3D]
#
#                     ToolsTechWantToWorkWith  \
# 61918  [Docker, Git, Kubernetes, Terraform]
# 12027                                 [Git]
# 68485                       [Git, Unity 3D]
#
#                             NEWCollabToolsHaveWorkedWith  \
# 61918                                              [Vim]
# 12027  [IntelliJ, Vim, Visual Studio, Visual Studio C...
# 68485  [Eclipse, Notepad++, Visual Studio, Visual Stu...
#
#                             NEWCollabToolsWantToWorkWith    OpSys
# 61918                     [IPython/Jupyter, Neovim, Vim]    MacOS
# 12027                          [Vim, Visual Studio Code]  Windows
# 68485  [Eclipse, Notepad++, Visual Studio, Visual Stu...  Windows

# %% [markdown]
# ### Export Data

# %%
df_processed.to_pickle(f'{PROCESSED_DATA_PATH}/1_preprocessed_df.pkl')
